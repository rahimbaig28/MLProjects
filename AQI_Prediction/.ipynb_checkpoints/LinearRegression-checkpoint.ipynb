# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", "\nPyarrow", DeprecationWarning)

# %%
df = pd.read_csv("Real_Combine.csv")

# %%
df.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM      PM 2.5
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4  219.720833
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1  182.187500
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1  154.037500
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6  223.208333
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2  200.645833

# %%
df.isnull().sum()
# Out:
# T         0
# TM        0
# Tm        0
# SLP       0
# H         0
# VV        0
# V         0
# VM        0
# PM 2.5    0
# dtype: int64

# %%
df=df.dropna()

# %%
X=df.iloc[:,:-1]
y=df. iloc[:,-1]

# %%
df.corr()
# Out:
#                T        TM        Tm       SLP         H        VV         V  \
# T       1.000000  0.967536  0.953719 -0.881409 -0.509299  0.640792  0.301994
# TM      0.967536  1.000000  0.892031 -0.822958 -0.586681  0.606945  0.292949
# Tm      0.953719  0.892031  1.000000 -0.917518 -0.287357  0.577240  0.296225
# SLP    -0.881409 -0.822958 -0.917518  1.000000  0.240256 -0.517915 -0.329838
# H      -0.509299 -0.586681 -0.287357  0.240256  1.000000 -0.465374 -0.380575
# VV      0.640792  0.606945  0.577240 -0.517915 -0.465374  1.000000  0.376873
# V       0.301994  0.292949  0.296225 -0.329838 -0.380575  0.376873  1.000000
# VM      0.287738  0.297011  0.266782 -0.310704 -0.362177  0.342442  0.775655
# PM 2.5 -0.631462 -0.568409 -0.673824  0.623187  0.138005 -0.573941 -0.268530
#
#               VM    PM 2.5
# T       0.287738 -0.631462
# TM      0.297011 -0.568409
# Tm      0.266782 -0.673824
# SLP    -0.310704  0.623187
# H      -0.362177  0.138005
# VV      0.342442 -0.573941
# ...

# %%
import seaborn as sns
corrmat= df.corr()
top_corr_features = corrmat.index

g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap='coolwarm')

# %%
X.head()
# Out:
#       T    TM   Tm     SLP     H   VV    V    VM
# 0   7.4   9.8  4.8  1017.6  93.0  0.5  4.3   9.4
# 1   7.8  12.7  4.4  1018.5  87.0  0.6  4.4  11.1
# 2   6.7  13.4  2.4  1019.4  82.0  0.6  4.8  11.1
# 3   8.6  15.5  3.3  1018.7  72.0  0.8  8.1  20.6
# 4  12.4  20.9  4.4  1017.3  61.0  1.3  8.7  22.2

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
print(model.feature_importances_) #to select the important features
# Out:
# [0.17814727 0.11514011 0.22907911 0.10386955 0.08765904 0.19001926
#  0.05247458 0.04361109]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns) 
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
sns.displot(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor=LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
'''
This line of code will output the coefficient of determination, 
𝑅2, for your training set, indicating how well your regression model fits the training data
'''
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_train, y_train)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.551516808175875

# %%
print("Coefficient of determination R^2 <-- on train set: {}".format(regressor.score(X_test, y_test)))
# Out:
# Coefficient of determination R^2 <-- on train set: 0.48525331308567876

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(regressor,X,y,cv=5)

# %%
score.mean()
# Out:
# 0.4710569304807393

# %%
#Model Evaluation
coeff_df = pd.DataFrame(regressor.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#      Coefficient
# T      -2.690908
# TM      0.462200
# Tm     -3.867052
# SLP    -0.044949
# H      -1.211936
# VV    -40.114908
# V      -2.535633
# VM      0.561482

# %%
prediction=regressor.predict(X_test)

# %%
sns.displot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, prediction))
print('MSE:', metrics.mean_squared_error(y_test, prediction))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prediction)))
# Out:
# MAE: 44.8362412662864
# MSE: 3687.5430309324192
# RMSE: 60.725143317512384

# %%
import pickle 
# open a file, where you ant to store the data
file = open('regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(regressor, file)
